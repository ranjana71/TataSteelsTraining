# %%
#1:  use car sales data set for this assignment
import pandas as pd

# %%
df=pd.read_csv('D:/Car_sales.csv')

# %%
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8         1.0      101.2
# ...

# %%
# 2: print the number of rows from this data set
len(df)
# Out:
# 157

# %%
# 3: print the index of the data frame

df.index
# Out:
# RangeIndex(start=0, stop=157, step=1)

# %%
#4:  print the number of columns
len(df.columns)
# Out:
# 16

# %%
# 5: Print a list of manufacturers in the data set
df['Manufacturer'].unique()
# Out:
# array(['Acura', 'Audi', 'BMW', 'Buick', 'Cadillac', 'Chevrolet',
#        'Chrysler', 'Dodge', 'Ford', 'Honda', 'Hyundai', 'Infiniti',
#        'Jaguar', 'Jeep', 'Lexus', 'Lincoln', 'Mitsubishi', 'Mercury',
#        'Mercedes-B', 'Nissan', 'Oldsmobile', 'Plymouth', 'Pontiac',
#        'Porsche', 'Saab', 'Saturn', 'Subaru', 'Toyota', 'Volkswagen',
#        'Volvo'], dtype=object)

# %%
# 6: print the total of Sales_in_thousands column
df[['Sales_in_thousands']].sum()
# Out:
# Sales_in_thousands    8320.698
# dtype: float64

# %%
#s 7: how the maximum price of car in all categories of Vehicle_type
df.groupby(['Vehicle_type'])[['Price_in_thousands']].max()
# Out:
#               Price_in_thousands
# Vehicle_type
# Car                       60.105
# Passenger                 85.500

# %%
# 8: print the model whose horsepower is the maximum
df1=df[['Model','Horsepower']][df['Horsepower'] == df['Horsepower'].max()]
df1
# Out:
#     Model  Horsepower
# 39  Viper       450.0

# %%
#9 :drop column with the highest number of NA. DON'T make the change permanent
df.isna().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Vehicle_type            0
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# dtype: int64

# %%
df.drop(["__year_resale_value"],axis = 1)
# Out:
#     Manufacturer    Model  Sales_in_thousands Vehicle_type  \
# 0          Acura  Integra              16.919    Passenger
# 1          Acura       TL              39.384    Passenger
# 2          Acura       CL              14.114    Passenger
# 3          Acura       RL               8.588    Passenger
# 4           Audi       A4              20.397    Passenger
# ..           ...      ...                 ...          ...
# 152        Volvo      V40               3.545    Passenger
# 153        Volvo      S70              15.245    Passenger
# 154        Volvo      V70              17.531    Passenger
# 155        Volvo      C70               3.493    Passenger
# 156        Volvo      S80              18.969    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0                 21.50          1.8         1.0      101.2   67.3   172.4
# 1                 28.40          3.2       225.0      108.1   70.3   192.9
# ...

# %%
#10 : show the name of manufacture whose sales were highest
df2=df[['Manufacturer','Sales_in_thousands']][df['Sales_in_thousands'] == df['Sales_in_thousands'].max()]
df2
# Out:
#    Manufacturer  Sales_in_thousands
# 56         Ford             540.561

# %%
# 11 show data of cars whose latest launch was in 2011
import numpy as np
import datetime

# %%
# Step 1  convert launch_year date format to year & append to data frame
df['year'] = pd.DatetimeIndex(df['Latest_Launch']).year
#df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8         1.0      101.2
# ...

# %%
#Step 2 : Filter based on year
condition = (df ['year'] == 2011)   
df[condition]
# Out:
#     Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 1          Acura    TL              39.384               19.875    Passenger
# 3          Acura    RL               8.588               29.725    Passenger
# 4           Audi    A4              20.397               22.255    Passenger
# 5           Audi    A6              18.780               23.555    Passenger
# 7            BMW  323i              19.747                  NaN    Passenger
# ..           ...   ...                 ...                  ...          ...
# 151        Volvo   S40              16.957                  NaN    Passenger
# 152        Volvo   V40               3.545                  NaN    Passenger
# 154        Volvo   V70              17.531                  NaN    Passenger
# 155        Volvo   C70               3.493                  NaN    Passenger
# 156        Volvo   S80              18.969                  NaN    Passenger
#
# ...

# %%
# 12  show data of cars whose fuel efficiency was between 10 to 15
condn = (df['Fuel_efficiency'].between(10,15)) 
df[condn]
# Out:
#     Manufacturer         Model  Sales_in_thousands  __year_resale_value  \
# 18      Cadillac      Escalade              14.785                  NaN
# 41         Dodge     Ram Wagon              16.767                15.51
# 74         Lexus         LX470               9.126                  NaN
# 78       Lincoln     Navigator              22.925                  NaN
# 144       Toyota  Land Cruiser               9.835                34.08
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 18           Car              46.225          5.7       255.0      117.5
# 41           Car              21.315          3.9       175.0      109.6
# 74           Car              60.105          4.7       230.0      112.2
# 78           Car              42.660          5.4       300.0      119.0
# 144          Car              51.728          4.7       230.0      112.2
#
#      Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# ...

# %%
# 13: show count of vehicles in every vehicle type. Visualize your output as a graph
df['Vehicle_type'].value_counts()
# Out:
# Passenger    116
# Car           41
# Name: Vehicle_type, dtype: int64

# %%
import seaborn as sns

# %%
sns.countplot(x='Vehicle_type',data=df)
