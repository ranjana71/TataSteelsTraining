# %%
import pandas as pd
import numpy as np #numpy
import seaborn as sns #visual charts , matplotlib
import sys
sys.version
# Out:
# '3.7.10 (default, Feb 26 2021, 13:06:18) [MSC v.1916 64 bit (AMD64)]'

# %%
df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
"""
Find the average Fare paid by Titanic passengers above 
20 years of age categorized by Gender 
"""
newdf = df[(df.Age >20)]
newdf.groupby( ['Sex'] )[['Fare']].mean()
# Out:
#              Fare
# Sex
# female  52.638338
# male    27.757062

# %%
"""
Find the count of passengers between age group of 20-45 categorized by Gender and Pclass
"""
#condition = ( df ['Age'].between(20,25) )
#df[['col1', 'col2', 'col3', 'col4']].groupby(['col1', 'col2']).agg(['mean', 'count']
# Out:
# '\nFind the count of passengers between age group of 20-45 categorized by Gender and Pclass\n'

# %%
#Filter age grp of 20 -45
newdf1 = df[( df ['Age'].between(20,45) )]
newdf1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Group by Gender , Pclass for count of passengers
newdf1.groupby( ['Sex','Pclass'] )[['PassengerId']].count()
# Out:
#                PassengerId
# Sex    Pclass
# female 1                51
#        2                51
#        3                54
# male   1                52
#        2                64
#        3               175

# %%
"""
Plot the count of Passengers in Pclass 3 above 40 years of age categorized by Gender

"""
newdf2 = df[( df ['Pclass'] == 3) & ( df ['Age']> 40) ]
newdf2.groupby( ['Sex'] )[['PassengerId']].count()
# Out:
#         PassengerId
# Sex
# female            9
# male             31

# %%
sns.countplot(x='Sex',data=newdf2, palette='magma')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
"""
Create a data frame that shows data of first 50 and last 80 passengers in the dataset
"""
dftop = df.head(50)
dfbot = df.tail(80)
dfconcat = pd.concat([dftop,dfbot],axis=0)
dfconcat
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
"""
show the quantile values of Fare for passengers of Pclass 1 and Pclass 2
"""
#df[['Pclass']].quantile(0.9) 
#df.groupby('key').quantile()
newdf5 = df[( df ['Pclass'].between(1,2))][['Pclass','Fare']]
newdf5
# Out:
#      Pclass     Fare
# 1         1  71.2833
# 3         1  53.1000
# 6         1  51.8625
# 9         2  30.0708
# 11        1  26.5500
# ..      ...      ...
# 880       2  26.0000
# 883       2  10.5000
# 886       2  13.0000
# 887       1  30.0000
# 889       1  30.0000
#
# [400 rows x 2 columns]

# %%
newdf5.groupby('Pclass').quantile()
# Out:
#            Fare
# Pclass
# 1       60.2875
# 2       14.2500

# %%
"""
Complete the following questions

-convert the above dictionaries into data frames with indices set as 1,2,3,4,5 and 3,4,2,1,5
for the second frame
-find the average temperature for cities common in 2 frames
-find the city with maximum temperature
-show records of cities which are not common in 2 frames
"""

# %%
#-convert the above dictionaries into data frames with indices set as 1,2,3,4,5 and 3,4,2,1,5
#for the second frame
d1={
    "City":['Mumbai','New York','London','Tokyo'],
    "Temperature":[27,19,17,28]
    }
df1=pd.DataFrame(d1,index=[1,2,3,4])

d2={
    "City":['Mumbai','New York','London','Melbourne'],
    "Humidity":[50,28,40,35]
    }

df2=pd.DataFrame(d2, index=[3,4,2,1] )

# %%
df1
# Out:
#        City  Temperature
# 1    Mumbai           27
# 2  New York           19
# 3    London           17
# 4     Tokyo           28

# %%
df2
# Out:
#         City  Humidity
# 3     Mumbai        50
# 4   New York        28
# 2     London        40
# 1  Melbourne        35

# %%
#find the average temperature for cities common in 2 frames
df6 = df1.merge(df2, on='City',how='inner')
df6
# Out:
#        City  Temperature  Humidity
# 0    Mumbai           27        50
# 1  New York           19        28
# 2    London           17        40

# %%
#find the city with maximum temperature
#df[['Age','Fare']].agg(['mean','sum','max','min'])
df6.sort_values(by=['Temperature'],ascending=[False])
df6.head(1)
# Out:
#      City  Temperature  Humidity
# 0  Mumbai           27      50.0

# %%
#-show records of cities which are not common in 2 frames
df7 = df1.merge(df2, on='City',how='outer')
df7
# Out:
#         City  Temperature  Humidity
# 0     Mumbai         27.0      50.0
# 1   New York         19.0      28.0
# 2     London         17.0      40.0
# 3      Tokyo         28.0       NaN
# 4  Melbourne          NaN      35.0

# %%
is_NaN = df7.isnull()
row_has_NaN = is_NaN.any(axis=1)
rows_with_NaN = df7[row_has_NaN]
rows_with_NaN
# Out:
#         City  Temperature  Humidity
# 3      Tokyo         28.0       NaN
# 4  Melbourne          NaN      35.0

# %%
"""
Find the average Opening price in the month of January year for all years in the data set
"""
import datetime

#df=pd.read_csv("D:/YESBANK.NS.csv", parse_dates=['Date'], index_col='Date')
df=pd.read_csv("D:/YESBANK.NS.csv")
df['Year'] = pd.DatetimeIndex(df['Date']).year
df['Month'] = pd.DatetimeIndex(df['Date']).month

df1 = df[( df['Month'] == 1) ]
df1.groupby(['Year'])[['Open']].mean()
# Out:
#             Open
# Year
# 2018  340.177274
# 2019  197.308696
# 2020   42.582609

# %%
"""
Find the average Opening price in the month of January year for all years in the data set
"""
import datetime

#df=pd.read_csv("D:/YESBANK.NS.csv", parse_dates=['Date'], index_col='Date')
df_x=pd.read_csv("D:/YESBANK.NS.csv", parse_dates=['Date'], index_col='Date')
#df_x.loc[ : ].resample('M')[['Open']].agg(['mean']
                                             
df_y= df_x.loc[   :  ].resample('M').agg(['mean']).loc[ : , 'Open']

df_y
df_x
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-12-11  313.500000  315.799988  310.600006  311.600006  300.880615
# 2017-12-12  312.000000  312.000000  305.899994  306.799988  296.245758
# 2017-12-13  306.350006  307.350006  301.049988  301.899994  291.514282
# 2017-12-14  303.899994  304.649994  301.750000  303.899994  293.445526
# 2017-12-15  307.000000  317.450012  307.000000  315.899994  305.032715
# ...                ...         ...         ...         ...         ...
# 2020-12-02   15.700000   15.900000   14.850000   15.450000   15.450000
# 2020-12-03   15.650000   15.800000   15.250000   15.450000   15.450000
# 2020-12-04   15.600000   15.600000   15.050000   15.350000   15.350000
# 2020-12-07   15.650000   15.850000   15.500000   15.750000   15.750000
# 2020-12-08   16.000000   17.299999   16.000000   17.299999   17.299999
#
#                  Volume
# Date
# 2017-12-11    4416465.0
# 2017-12-12    5457103.0
# 2017-12-13    6911856.0
# ...

# %%
df_x.groupby(df_x.index.month_name())[['Open']].mean().loc['January']
# Out:
# Open    191.197059
# Name: January, dtype: float64

# %%
"""
Find the month in which the lowest average Adjusted Closing price was obeserved
"""
df1 =df.groupby(['Year','Month'])[['Adj Close']].mean()
#Use idxmin() function with ‘axis = 1’ attribute to find the index/label of the minimum value along the column axis.
minvalueIndexLabel = df1.idxmin()
  
minvalueIndexLabel
# Out:
# Adj Close    (2020, 10)
# dtype: object

# %%
#to confirm answer
df1
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 14   2018-01-01  315.500000  317.750000  311.299988  312.600006  301.846252
# 15   2018-01-02  313.399994  314.000000  307.149994  311.649994  300.928894
# 16   2018-01-03  312.000000  316.500000  311.149994  315.850006  304.984436
# 17   2018-01-04  316.000000  318.399994  313.000000  317.100006  306.191437
# 18   2018-01-05  317.500000  337.899994  317.450012  332.850006  321.399628
# ..          ...         ...         ...         ...         ...         ...
# 498  2019-12-24   50.150002   52.000000   50.049999   51.200001   51.200001
# 499  2019-12-26   51.000000   51.599998   48.250000   48.650002   48.650002
# 500  2019-12-27   49.500000   49.750000   47.650002   48.000000   48.000000
# 501  2019-12-30   47.900002   48.950001   46.650002   47.349998   47.349998
# 502  2019-12-31   47.299999   48.049999   46.349998   46.950001   46.950001
#
#           Volume  Year  Month
# ...

# %%
#Alternate 2  
#Find the month in which the lowest average Adjusted Closing price was obeserved
df=pd.read_csv("D:/YESBANK.NS.csv", parse_dates=['Date'], index_col='Date')
#df.head(5)
df1=df.resample('M')[['Adj Close']].agg(['mean'])
dminValuesObj = df1.min()
minValue = df1['Adj Close'].min()

minValue
# Out:
# mean    12.930952
# dtype: float64

# %%
minValuesObj = df1.min()
minValue = df1['Adj Close'].min()

minValueIndexObj = df1.idxmin()
minValueIndexObj
# Out:
# Adj Close  mean   2020-10-31
# dtype: datetime64[ns]

# %%
"""
Plot a line plot to show the trend in average Close price every quarter in the year 2019
"""
df_0=pd.read_csv("D:/YESBANK.NS.csv", parse_dates=['Date'], index_col='Date')
df_1=df_0.loc['2019',['Close']].resample('Q').agg({'Close':'mean'})
df_1
# Out:
#                  Close
# Date
# 2019-03-31  213.219168
# 2019-06-30  175.597500
# 2019-09-30   76.409678
# 2019-12-31   55.302500

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

# %%
sns.lineplot(x='Date',y='Close',data=df_1 )
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Close'>

# %%
"""
plot a graph to show the relationship between Open and closing price for every quarter in 
2019
"""
"""
Show the count of passengers distributed by their Embarked location as a multiplot
"""

"""
Prove statistically & graphically that average closing price was higher in 2018 than in 2019
"""

# %%
df_2=df_0.resample('Q').mean()
df_2
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-12-31  311.528571  314.225000  308.385712  311.078570  300.377130
# 2018-03-31  326.297501  331.081666  320.560833  326.034165  314.818244
# 2018-06-30  333.562501  338.151565  328.586719  333.024219  322.371330
# 2018-09-30  351.062295  355.870492  342.286065  347.971310  338.668961
# 2018-12-31  198.200820  204.227869  191.972952  197.831967  192.543306
# 2019-03-31  212.894167  217.987500  208.054167  213.219168  207.519160
# 2019-06-30  178.466667  181.811666  172.231666  175.597500  171.911110
# 2019-09-30   77.699194   80.258871   73.682258   76.409678   76.409678
# 2019-12-31   55.485000   58.127500   52.929167   55.302500   55.302500
# 2020-03-31   38.357143   40.835715   35.349206   37.626190   37.626190
# 2020-06-30   27.378814   28.183051   26.610169   27.343220   27.343220
# 2020-09-30   16.314394   16.662121   15.852273   16.209848   16.209848
# ...

# %%
import datetime as dt
import pandas as pd

# %%
df=pd.read_csv("D:/YESBANK.NS.csv")
dfa.Date = pd.to_datetime(dfa.Date)
dfa['quarter'] = pd.PeriodIndex(dfa.Date, freq='Q')
df2019 = dfa[( dfa['quarter'] .between('2019Q1', '2019Q4')) ]
df2019
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 260 2019-01-01  182.600006  185.899994  181.000000  184.250000  179.324417
# 261 2019-01-02  183.449997  187.000000  182.500000  184.649994  179.713730
# 262 2019-01-03  185.250000  186.000000  183.500000  184.100006  179.178436
# 263 2019-01-04  184.850006  190.300003  181.550003  189.649994  184.580063
# 264 2019-01-07  193.899994  194.399994  185.800003  187.149994  182.146896
# ..         ...         ...         ...         ...         ...         ...
# 498 2019-12-24   50.150002   52.000000   50.049999   51.200001   51.200001
# 499 2019-12-26   51.000000   51.599998   48.250000   48.650002   48.650002
# 500 2019-12-27   49.500000   49.750000   47.650002   48.000000   48.000000
# 501 2019-12-30   47.900002   48.950001   46.650002   47.349998   47.349998
# 502 2019-12-31   47.299999   48.049999   46.349998   46.950001   46.950001
#
#           Volume quarter
# 260   24160878.0  2019Q1
# ...

# %%
plt.figure(figsize=(10,5))

g=sns.FacetGrid(data=df2019,col='quarter', hue='quarter')
g.map(sns.lineplot,'Open','Close')

#grid = sns.FacetGrid(df2019, col = "quarter", hue = "quarter", col_wrap=4)
#g.map(sns.scatterplot,'Open','Close')

grid.add_legend()

plt.show()

# %%
"""
Prove statistically & graphically that average closing price was higher in 2018 than in 2019
"""
# Out:
# '\nProve statistically & graphically that average closing price was higher in 2018 than in 2019\n'

# %%
import datetime

#df=pd.read_csv("D:/YESBANK.NS.csv", parse_dates=['Date'], index_col='Date')
df_a=pd.read_csv("D:/YESBANK.NS.csv")
df_a['Year'] = pd.DatetimeIndex(df_a['Date']).year
df_a['Month'] = pd.DatetimeIndex(df_a['Date']).month
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2017-12-11  313.500000  315.799988  310.600006  311.600006  300.880615
# 1    2017-12-12  312.000000  312.000000  305.899994  306.799988  296.245758
# 2    2017-12-13  306.350006  307.350006  301.049988  301.899994  291.514282
# 3    2017-12-14  303.899994  304.649994  301.750000  303.899994  293.445526
# 4    2017-12-15  307.000000  317.450012  307.000000  315.899994  305.032715
# ..          ...         ...         ...         ...         ...         ...
# 733  2020-12-02   15.700000   15.900000   14.850000   15.450000   15.450000
# 734  2020-12-03   15.650000   15.800000   15.250000   15.450000   15.450000
# 735  2020-12-04   15.600000   15.600000   15.050000   15.350000   15.350000
# 736  2020-12-07   15.650000   15.850000   15.500000   15.750000   15.750000
# 737  2020-12-08   16.000000   17.299999   16.000000   17.299999   17.299999
#
#           Volume  Year  Month
# ...

# %%
"""
Prove  graphically that average closing price was higher in 2018 than in 2019
"""
df1 = df[( df['Year'].between (2018,2019))]


#df2019 = dfa[( dfa['quarter'] .between('2019Q1', '2019Q4')) ]
plt.figure(figsize=(10,5))

sns.lineplot(x='Month',
             y='Close',
             data=df1,hue='Year',palette='winter'        
            )
plt.title('Trend of Closing price 2018-2019')
plt.show()

# %%
#Statistically average closing price was higher in 2018 than in 2019
dfa=pd.read_csv("D:/YESBANK.NS.csv", parse_dates=['Date'], index_col='Date')
#df.head(5)

dfa.loc[  '2018' : '2019' ].resample('Y')[['Close']].agg(['min','max','mean'])
# Out:
#                  Close
#                    min         max        mean
# Date
# 2018-12-31  160.449997  394.000000  301.502438
# 2019-12-31   32.000000  280.299988  129.688223

# %%
getcwd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-495-8fbe4ae84dae> in <module>
# ----> 1 getcwd
#
# NameError: name 'getcwd' is not defined
